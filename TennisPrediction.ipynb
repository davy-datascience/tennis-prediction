# %% [markdown]
# # Tennis match winner prediction

# %% [markdown]
# Tennis is a subject that passionates me since I am a child. That's why I choose this subject.
#
# I will be trying to predict ATP match winners

# %% [markdown]
# ## Data Collection

# %% [markdown]
# I found ATP match data from 2000 to 2017 on kaggle: https://www.kaggle.com/gmadevs/atp-matches-dataset
#
# On the Acknowledgement section I found the Git repo where the up-to-date data is available: https://github.com/JeffSackmann/tennis_atp
#
# From there I extracted data from XX to 2020.

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# First I tried to test a very simple model using those features:
# - *winner_rank_points*
# - *loser_rank_points*
#
# I chose *rank_points* features over *rank* features because there can be a either small or huge difference of rank points between for example the 2nd ATP player and the 3rd ATP player.
# <br>
# rank_points are more meaningfull than the rank of a player.
# <br>
# I didn't pick both features to avoid **multicollinearity** that would weaken my model.
# <br><br>
# I encountered a problem: in the dataset, the features *winner_rank_points* and *loser_rank_points* are related to the player that will either win or lose the match. To avoid **target leakage**, I rename those features as *player_1_points* and *player_2_points* and added the independent variable *p1_wins*
